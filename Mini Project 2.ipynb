# %% [markdown]
# # Mortality and Fertility

# %% [markdown]
# In this file, I have found the relationship between fertility rate and infant mortality rate in Pakistan.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
indicator = pd.read_csv('./Python_DS/Week5_Matplotlib/World-development/Indicators.csv')
indicator.shape
# Out:
# (5656458, 6)

# %%
indicator.dropna(axis=0)
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# 5        Arab World         ARB
# 6        Arab World         ARB
# 7        Arab World         ARB
# 8        Arab World         ARB
# 9        Arab World         ARB
# 10       Arab World         ARB
# 11       Arab World         ARB
# 12       Arab World         ARB
# 13       Arab World         ARB
# 14       Arab World         ARB
# 15       Arab World         ARB
# 16       Arab World         ARB
# 17       Arab World         ARB
# 18       Arab World         ARB
# 19       Arab World         ARB
# 20       Arab World         ARB
# 21       Arab World         ARB
# 22       Arab World         ARB
# 23       Arab World         ARB
# 24       Arab World         ARB
# 25       Arab World         ARB
# 26       Arab World         ARB
# 27       Arab World         ARB
# ...

# %%
indicator.dropna(axis=1)
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# 5        Arab World         ARB
# 6        Arab World         ARB
# 7        Arab World         ARB
# 8        Arab World         ARB
# 9        Arab World         ARB
# 10       Arab World         ARB
# 11       Arab World         ARB
# 12       Arab World         ARB
# 13       Arab World         ARB
# 14       Arab World         ARB
# 15       Arab World         ARB
# 16       Arab World         ARB
# 17       Arab World         ARB
# 18       Arab World         ARB
# 19       Arab World         ARB
# 20       Arab World         ARB
# 21       Arab World         ARB
# 22       Arab World         ARB
# 23       Arab World         ARB
# 24       Arab World         ARB
# 25       Arab World         ARB
# 26       Arab World         ARB
# 27       Arab World         ARB
# ...

# %% [markdown]
# After dropping the null value the shape remains shape which implies that there was no null value in the data

# %%
indicator.shape
# Out:
# (5656458, 6)

# %%
fertility_rate = indicator['IndicatorName'] == 'Fertility rate, total (births per woman)'

# %%
indicator[fertility_rate][:]
# Out:
#                                             CountryName CountryCode  \
# 14                                           Arab World         ARB
# 93                               Caribbean small states         CSS
# 182                      Central Europe and the Baltics         CEB
# 259             East Asia & Pacific (all income levels)         EAS
# 372               East Asia & Pacific (developing only)         EAP
# 511                                           Euro area         EMU
# 617           Europe & Central Asia (all income levels)         ECS
# 723             Europe & Central Asia (developing only)         ECA
# 829                                      European Union         EUU
# 920            Fragile and conflict affected situations         FCS
# 999              Heavily indebted poor countries (HIPC)         HPC
# 1120                                        High income         HIC
# 1223                               High income: nonOECD         NOC
# ...

# %%
mortality_rate = indicator['IndicatorName'] == 'Mortality rate, infant (per 1,000 live births)'

# %%
pakistan = indicator['CountryName'].str.contains('Pakistan')

# %%
indicator[pakistan]
# Out:
#         CountryName CountryCode  \
# 16983      Pakistan         PAK
# 16984      Pakistan         PAK
# 16985      Pakistan         PAK
# 16986      Pakistan         PAK
# 16987      Pakistan         PAK
# 16988      Pakistan         PAK
# 16989      Pakistan         PAK
# 16990      Pakistan         PAK
# 16991      Pakistan         PAK
# 16992      Pakistan         PAK
# 16993      Pakistan         PAK
# 16994      Pakistan         PAK
# 16995      Pakistan         PAK
# 16996      Pakistan         PAK
# 16997      Pakistan         PAK
# 16998      Pakistan         PAK
# 16999      Pakistan         PAK
# 17000      Pakistan         PAK
# 17001      Pakistan         PAK
# 17002      Pakistan         PAK
# 17003      Pakistan         PAK
# 17004      Pakistan         PAK
# 17005      Pakistan         PAK
# 17006      Pakistan         PAK
# 17007      Pakistan         PAK
# 17008      Pakistan         PAK
# 17009      Pakistan         PAK
# 17010      Pakistan         PAK
# ...

# %%
mask1 = indicator[mortality_rate & pakistan]

# %%
#result = indicator[fertility_rate].append(indicator[mortality_rate])
#result = indicator[mortality_rate]

# %%
mask1
# Out:
#         CountryName CountryCode  \
# 17099      Pakistan         PAK
# 42785      Pakistan         PAK
# 70755      Pakistan         PAK
# 99327      Pakistan         PAK
# 128277     Pakistan         PAK
# 159574     Pakistan         PAK
# 191139     Pakistan         PAK
# 223613     Pakistan         PAK
# 256148     Pakistan         PAK
# 289041     Pakistan         PAK
# 344008     Pakistan         PAK
# 411005     Pakistan         PAK
# 480302     Pakistan         PAK
# 549856     Pakistan         PAK
# 619737     Pakistan         PAK
# 691537     Pakistan         PAK
# 764670     Pakistan         PAK
# 839645     Pakistan         PAK
# 915125     Pakistan         PAK
# 991042     Pakistan         PAK
# 1070878    Pakistan         PAK
# 1154417    Pakistan         PAK
# 1239314    Pakistan         PAK
# 1324786    Pakistan         PAK
# 1410508    Pakistan         PAK
# 1497454    Pakistan         PAK
# 1585256    Pakistan         PAK
# 1674298    Pakistan         PAK
# ...

# %% [markdown]
# It is an exploratory visualization

# %%
mask2 = indicator[fertility_rate & pakistan]

# %%
mask2
# Out:
#         CountryName CountryCode                             IndicatorName  \
# 17012      Pakistan         PAK  Fertility rate, total (births per woman)
# 42689      Pakistan         PAK  Fertility rate, total (births per woman)
# 70651      Pakistan         PAK  Fertility rate, total (births per woman)
# 99221      Pakistan         PAK  Fertility rate, total (births per woman)
# 128171     Pakistan         PAK  Fertility rate, total (births per woman)
# 159462     Pakistan         PAK  Fertility rate, total (births per woman)
# 191033     Pakistan         PAK  Fertility rate, total (births per woman)
# 223481     Pakistan         PAK  Fertility rate, total (births per woman)
# 256014     Pakistan         PAK  Fertility rate, total (births per woman)
# 288907     Pakistan         PAK  Fertility rate, total (births per woman)
# 343846     Pakistan         PAK  Fertility rate, total (births per woman)
# 410835     Pakistan         PAK  Fertility rate, total (births per woman)
# ...

# %%
rate = result['Value'].values

# %%
# Scatter plot that shows relationship between mortality and fertility rate
plt.figure(figsize=(20,15))
new = (mask2['Value'].values)*20

# Scatter plot the mortality rate
plt.scatter(mask1['Year'].values, mask1['Value'].values, color = "purple")

# Scatter plot the 3 times fertility rate
plt.scatter(mask2['Year'].values, new, color = "red")

# Label the axes
plt.xlabel('Years')

#Label the figure
plt.title('Relationship between Fertility and Infant Mortality')

# Add a legend
plt.legend(('Infant Mortality in Pakistan', 'Fertility * 20 in Pakistan'), loc='upper right');

plt.show()

# %%
# Line plot that shows fertility rate over the years
plt.figure(figsize=(20,8))
plt.scatter(mask2['Year'].values, mask2['Value'].values, label="Year")

# Label the axes
plt.xlabel('Years')
plt.ylabel(result['IndicatorName'].iloc[0])


#plt.show()
# Out:
# Text(0, 0.5, 'Fertility rate, total (births per woman)')
